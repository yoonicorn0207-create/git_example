# %%
pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
inDf = pd.read_csv("./dataset/sample.txt")
inDf
# Out:
#   regionid   qty
# 0      a01   100

# %%
# try - Exeception 기능 추가
try:
    inDf = pd.read_csv("./dataset/sample.txt")
    inDf
except exception as e :
    print(e)

# %%
inDf
# Out:
#   regionid   qty
# 0      a01   100

# %%
# load .enc파일가져오기
# 이미지 파일 추가
